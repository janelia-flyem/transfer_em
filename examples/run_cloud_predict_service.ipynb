# %% [markdown]
# ### Use Google AI Platform to Run Prediction on the Cloud
#
# (Currently does not work since 2.1 is not supported for custom functions)

# %%
from transfer_em.predict_cloud import predict_cloud

# %%
model = "hemi_clahe_transfer"
version = "simple"
location="neuroglancer-janelia-flyem-hemibrain/emdata/raw/jpeg"
cloudrun="https://transferem-bmcp5imp6q-uk.a.run.app"
start=[8000, 14000, 13000]
size=[72, 72, 72]
project="flyem-private"

# %%
res = predict_cloud(project, model, location, cloudrun, start, size, version)
# Out:
# /Users/plazas/miniconda3/envs/tensorflow2/lib/python3.8/site-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# [{"location": "neuroglancer-janelia-flyem-hemibrain/emdata/raw/jpeg", "cloudrun": "https://transferem-bmcp5imp6q-uk.a.run.app", "start": [8000, 14000, 13000], "size": [72, 72, 72]}]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-14801ecc9a09> in <module>
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))                                                                                       
plt.subplot(121)
plt.title("input")
plt.imshow(res[:,:,50], cmap="gray", vmin=0, vmax=255)                                                            
plt.axis('off')
plt.subplot(122)
plt.title("output")
plt.imshow(res[:,:,50], cmap="gray", vmin=0, vmax=255)                                                            
plt.axis('off')
plt.show()
